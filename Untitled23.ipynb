# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Rafi07/-MongoDB-connection-string-in-the-.env-file-/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(load_iris().data, columns=load_iris().feature_names)

df['species'] = iris.target
df['species'] = df['species'].map({0:'Setosa', 1:'Versicolor' , 2:'Virginica'})
df.head()
df.info()
print(df.shape)
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# (150, 5)
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species               object
# dtype: object

# %%
df.isnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
#      species
# 0      False
# ...

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
print("Features in DataSet:")
print(df.columns)
# Out:
# Features in DataSet:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
df.mean(numeric_only=True)
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64

# %%
comparision = pd.DataFrame({
    'Mean':df.mean(numeric_only=True),
    'Median':df.median(numeric_only=True)
})
comparision
# Out:
#                        Mean  Median
# sepal length (cm)  5.843333    5.80
# sepal width (cm)   3.057333    3.00
# petal length (cm)  3.758000    4.35
# petal width (cm)   1.199333    1.30

# %%
cv  = (df.std(numeric_only=True) / df.mean(numeric_only=True)) * 100
cv
# Out:
# sepal length (cm)    14.171126
# sepal width (cm)     14.256420
# petal length (cm)    46.974407
# petal width (cm)     63.555114
# dtype: float64

# %%
cv.idxmax()
# Out:
# 'petal width (cm)'

# %%
from numpy._core import numeric
correlation_matrix = df.corr(numeric_only=True)
correlation_matrix
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
corr_matrix = correlation_matrix.abs()

np.fill_diagonal(corr_matrix.values, 0)
corr_matrix.unstack().sort_values(ascending=False).head(1)
# Out:
# petal width (cm)  petal length (cm)    0.962865
# dtype: float64

# %%
correlation_matrix.unstack().sort_values().drop_duplicates().head(5)
# Out:
# sepal width (cm)   petal length (cm)   -0.428440
# petal width (cm)   sepal width (cm)    -0.366126
# sepal length (cm)  sepal width (cm)    -0.117570
#                    petal width (cm)     0.817941
#                    petal length (cm)    0.871754
# dtype: float64

# %%
print("Petal length and petal width are highly correlated.")
print("Sepal width has weaker relationships with other features.")
# Out:
# Petal length and petal width are highly correlated.
# Sepal width has weaker relationships with other features.

# %%
species_group = df.groupby('species')
species_group.mean(numeric_only=True)
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# Setosa                  5.006             3.428              1.462
# Versicolor              5.936             2.770              4.260
# Virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# Setosa                 0.246
# Versicolor             1.326
# Virginica              2.026

# %%
species_group.mean(numeric_only=True)['petal length (cm)'].idxmax()
# Out:
# 'Virginica'

# %%
species_group.mean(numeric_only=True)['sepal width (cm)'].idxmin()
# Out:
# 'Versicolor'

# %%
species_group.mean(numeric_only=True)
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# Setosa                  5.006             3.428              1.462
# Versicolor              5.936             2.770              4.260
# Virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# Setosa                 0.246
# Versicolor             1.326
# Virginica              2.026

# %%
print("""
EXECUTIVE SUMMARY

1.Petal features shw the highest variation in the dataset.
2.Petal length and petal width are most useful for distinguishing species.
3.Strong positive correlation between sepal length and sepal width.
4.Setosa species is clearly different from the others due to samller petal measurements.
5.The dataset is clean with no missing values and is suitable for machine learning tasks.

""")
# Out:
# EXECUTIVE SUMMARY
#
# 1.Petal features shw the highest variation in the dataset.
# 2.Petal length and petal width are most useful for distinguishing species.
# 3.Strong positive correlation between sepal length and sepal width.
# 4.Setosa species is clearly different from the others due to samller petal measurements.
# 5.The dataset is clean with no missing values and is suitable for machine learning tasks.

# %% [markdown]
# EXECUTIVE SUMMARY
#
# 1.Petal features shw the highest variation in the dataset.
# 2.Petal length and petal width are most useful for distinguishing species.
# 3.Strong positive correlation between sepal length and sepal width.
# 4.Setosa species is clearly different from the others due to samller petal measurements.
# 5.The dataset is clean with no missing values and is suitable for machine learning tasks.
